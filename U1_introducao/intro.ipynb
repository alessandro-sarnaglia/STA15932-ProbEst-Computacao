# %% [raw]
# ---
# title: "Probabilidade e Estatística"
# subtitle: "Introdução e estatística descritiva"
# author: "Prof. Dr. Alessandro JQ Sarnaglia"
# format:
#   revealjs:
#     theme: simple
# editor: visual
#
#
# ```{css, echo = FALSE}
# p {
#   text-align: justify
# }
# ```
#
# ---

# %% [markdown]
# # Programa e avaliações
#
# ------------------------------------------------------------------------
#
# ### Programa
#
# ::: incremental
# 1.  Introdução e estatística descritiva;
# 2.  Probabilidade de eventos;
# 3.  Variáveis aleatórias;
# 4.  Inferência estatística.
# :::
#
# ::: fragment
# ### Bibliografia
#
# -   DEVORE, Jay L. Probabilidade e estatística: para engenharia e ciências. São Paulo: Cengage Learning, 2012;
# -   MORETTIN, Pedro Alberto; BUSSAB, Wilton de Oliveira. Estatística básica. 8ª ed. São Paulo: Saraiva, 2013.
# :::
#
# ------------------------------------------------------------------------
#
# ### Avaliações
#
# ::: incremental
# 1.  Avaliação 1 ⟹ Unidades 1 e 2;
# 2.  Avaliação 2 ⟹ Unidade 3;
# 3.  Avaliação 3 ⟹ Unidade 4.
# :::
#
# ::: fragment
# ::: {.fragment .highlight-red}
# **Importante:** datas serão definidas em conjunto com a turma.
# :::
# :::
#
# ::: fragment
# **Contatos e sala:**
#
# -   📧 alessandro.sarnaglia\@ufes.br;
# -   ☎️ (27) 4009-2822;
# -   🖥️ Sala 305 - Bloco B do IC1.
# :::
#
# # Estatística Descritiva
#
# ## Conceitos básicos
#
# **O que é Estatística?** campo da ciência que se dedica a coleta e análise de dados.
#
# **Importância:** a Estatística é capaz de auxiliar na tomada de decisões em situações que apresentam variação/incerteza.
#
# Nesse contexto, a **Estatística Descritiva** é o ramo da Estatística que se dedica a resumir e descrever características importantes dos dados.
